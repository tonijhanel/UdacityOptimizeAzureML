# %%
import logging
import json

# %%
pip install azureml-core
# Out:
# Requirement already satisfied: azureml-core in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (1.57.0)
# Requirement already satisfied: packaging<=25.0,>=20.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core) (24.1)
# Requirement already satisfied: azure-mgmt-authorization<5,>=0.40.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core) (4.0.0)
# Requirement already satisfied: requests[socks]<3.0.0,>=2.19.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core) (2.32.3)
# Requirement already satisfied: azure-mgmt-network<=26.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core) (25.1.0)
# Requirement already satisfied: backports.tempfile in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core) (1.0)
# Requirement already satisfied: msal-extensions<=2.0.0,>=0.3.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core) (1.2.0)
# Requirement already satisfied: urllib3<3.0.0,>1.26.17 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core) (1.26.19)
# Requirement already satisfied: pkginfo in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core) (1.11.1)
# Requirement already satisfied: knack<0.12.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core) (0.11.0)
# Requirement already satisfied: pyopenssl<25.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core) (23.0.0)
# Requirement already satisfied: azure-mgmt-keyvault<11.0.0,>=0.40.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core) (10.3.0)
# Requirement already satisfied: SecretStorage<4.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core) (3.3.3)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.7.3 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core) (2.9.0.post0)
# Requirement already satisfied: pathspec<1.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core) (0.12.1)
# Requirement already satisfied: PyJWT<3.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core) (2.4.0)
# Requirement already satisfied: contextlib2<22.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core) (21.6.0)
# Requirement already satisfied: azure-mgmt-resource<=24.0.0,>=15.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core) (23.1.1)
# Requirement already satisfied: argcomplete<4 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core) (3.3.0)
# Requirement already satisfied: azure-mgmt-storage<=22.0.0,>=16.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core) (21.2.0)
# Requirement already satisfied: azure-graphrbac<1.0.0,>=0.40.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core) (0.60.0)
# Requirement already satisfied: adal<=1.2.7,>=1.2.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core) (1.2.7)
# Requirement already satisfied: docker<8.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core) (7.1.0)
# Requirement already satisfied: azure-mgmt-containerregistry<11,>=8.2.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core) (10.3.0)
# Requirement already satisfied: msrestazure<=0.7,>=0.4.33 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core) (0.6.4.post1)
# Requirement already satisfied: msrest<=0.7.1,>=0.5.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core) (0.7.1)
# Requirement already satisfied: humanfriendly<11.0,>=4.7 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core) (10.0)
# Requirement already satisfied: azure-common<2.0.0,>=1.1.12 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core) (1.1.28)
# Requirement already satisfied: msal<2.0.0,>=1.15.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core) (1.30.0)
# Requirement already satisfied: azure-core<2.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core) (1.30.2)
# Requirement already satisfied: paramiko<4.0.0,>=2.0.8 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core) (3.4.0)
# Requirement already satisfied: ndg-httpsclient<=0.5.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core) (0.5.1)
# Requirement already satisfied: jmespath<2.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core) (0.10.0)
# Requirement already satisfied: jsonpickle<4.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core) (3.2.2)
# Requirement already satisfied: pytz in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core) (2022.5)
# Requirement already satisfied: cryptography>=1.1.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from adal<=1.2.7,>=1.2.0->azureml-core) (38.0.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azure-core<2.0.0->azureml-core) (4.12.2)
# Requirement already satisfied: six>=1.11.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azure-core<2.0.0->azureml-core) (1.16.0)
# Requirement already satisfied: isodate<1.0.0,>=0.6.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azure-mgmt-authorization<5,>=0.40.0->azureml-core) (0.6.1)
# Requirement already satisfied: azure-mgmt-core<2.0.0,>=1.3.2 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azure-mgmt-authorization<5,>=0.40.0->azureml-core) (1.4.0)
# Requirement already satisfied: tabulate in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from knack<0.12.0->azureml-core) (0.9.0)
# Requirement already satisfied: pyyaml in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from knack<0.12.0->azureml-core) (6.0.1)
# Requirement already satisfied: pygments in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from knack<0.12.0->azureml-core) (2.18.0)
# Requirement already satisfied: portalocker<3,>=1.4 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from msal-extensions<=2.0.0,>=0.3.0->azureml-core) (2.10.1)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from msrest<=0.7.1,>=0.5.1->azureml-core) (2.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from msrest<=0.7.1,>=0.5.1->azureml-core) (2024.8.30)
# Requirement already satisfied: pyasn1>=0.1.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ndg-httpsclient<=0.5.1->azureml-core) (0.6.0)
# Requirement already satisfied: pynacl>=1.5 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from paramiko<4.0.0,>=2.0.8->azureml-core) (1.5.0)
# Requirement already satisfied: bcrypt>=3.2 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from paramiko<4.0.0,>=2.0.8->azureml-core) (4.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from requests[socks]<3.0.0,>=2.19.1->azureml-core) (3.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from requests[socks]<3.0.0,>=2.19.1->azureml-core) (3.3.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from requests[socks]<3.0.0,>=2.19.1->azureml-core) (1.7.1)
# Requirement already satisfied: jeepney>=0.6 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from SecretStorage<4.0.0->azureml-core) (0.8.0)
# Requirement already satisfied: backports.weakref in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from backports.tempfile->azureml-core) (1.0.post1)
# Requirement already satisfied: cffi>=1.12 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from cryptography>=1.1.0->adal<=1.2.7,>=1.2.0->azureml-core) (1.16.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from requests-oauthlib>=0.5.0->msrest<=0.7.1,>=0.5.1->azureml-core) (3.2.2)
# Requirement already satisfied: pycparser in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=1.1.0->adal<=1.2.7,>=1.2.0->azureml-core) (2.22)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install cryptography
# Out:
# Requirement already satisfied: cryptography in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (38.0.4)
# Requirement already satisfied: cffi>=1.12 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from cryptography) (1.16.0)
# Requirement already satisfied: pycparser in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from cffi>=1.12->cryptography) (2.22)

# %%
from azureml.core import Workspace, Experiment

# %%
from azureml.core import Workspace, Experiment

ws = Workspace.from_config()
exp = Experiment(workspace=ws, name="udacity-project")

print('Workspace name: ' + ws.name, 
      'Azure region: ' + ws.location, 
      'Subscription id: ' + ws.subscription_id, 
      'Resource group: ' + ws.resource_group, sep = '\n')
# Out:
# Workspace name: mlcloud
# Azure region: eastus2
# Subscription id: d990bb6c-7849-4109-9dd7-6cafa051c8ae
# Resource group: mlcloud

# %%
import os

script_folder = './scripts'
os.makedirs(script_folder, exist_ok=True)

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.exceptions import ComputeTargetException

# %% [markdown]
# ### Create a compute cluster using the SDK.

# %%
# TODO: Create compute cluster
# Use vm_size = "Standard_D2_V2" in your provisioning configuration.
# max_nodes should be no greater than 4.

### YOUR CODE HERE ###
cluster_name = "c003"

try:
    compute_target = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing compute target {}.'.format(cluster_name))
except ComputeTargetException:
    print('Creating a new compute target...')
    compute_config = AmlCompute.provisioning_configuration(vm_size="Standard_D2_V2",
                                                               max_nodes=4)

    compute_target = ComputeTarget.create(ws, cluster_name, compute_config)
compute_target.wait_for_completion(show_output=True, timeout_in_minutes=20)

print("Azure Machine Learning Compute attached")
# Out:
# Found existing compute target c003.
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned
# Azure Machine Learning Compute attached

# %% [markdown]
# ### Use HyperDrive to automatically find optimal parameters.

# %% [markdown]
# ##

# %%
pip install azureml-widgets
# Out:
# Requirement already satisfied: azureml-widgets in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (1.57.0)
# Requirement already satisfied: jinja2<4.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-widgets) (3.1.4)
# Requirement already satisfied: azureml-telemetry~=1.57.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-widgets) (1.57.0)
# Requirement already satisfied: azureml-core~=1.57.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-widgets) (1.57.0)
# Requirement already satisfied: azure-storage-blob>=12.6.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-widgets) (12.13.0)
# Requirement already satisfied: ipywidgets<8.0.0,>=7.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-widgets) (7.7.1)
# Requirement already satisfied: msrest>=0.6.21 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azure-storage-blob>=12.6.0->azureml-widgets) (0.7.1)
# Requirement already satisfied: cryptography>=2.1.4 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azure-storage-blob>=12.6.0->azureml-widgets) (38.0.4)
# Requirement already satisfied: azure-core<2.0.0,>=1.23.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azure-storage-blob>=12.6.0->azureml-widgets) (1.30.2)
# Requirement already satisfied: msrestazure<=0.7,>=0.4.33 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-widgets) (0.6.4.post1)
# Requirement already satisfied: azure-mgmt-containerregistry<11,>=8.2.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-widgets) (10.3.0)
# Requirement already satisfied: backports.tempfile in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-widgets) (1.0)
# Requirement already satisfied: argcomplete<4 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-widgets) (3.3.0)
# Requirement already satisfied: humanfriendly<11.0,>=4.7 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-widgets) (10.0)
# Requirement already satisfied: contextlib2<22.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-widgets) (21.6.0)
# Requirement already satisfied: msal-extensions<=2.0.0,>=0.3.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-widgets) (1.2.0)
# Requirement already satisfied: azure-mgmt-resource<=24.0.0,>=15.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-widgets) (23.1.1)
# Requirement already satisfied: azure-graphrbac<1.0.0,>=0.40.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-widgets) (0.60.0)
# Requirement already satisfied: pathspec<1.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-widgets) (0.12.1)
# Requirement already satisfied: packaging<=25.0,>=20.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-widgets) (24.1)
# Requirement already satisfied: PyJWT<3.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-widgets) (2.4.0)
# Requirement already satisfied: jmespath<2.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-widgets) (0.10.0)
# Requirement already satisfied: adal<=1.2.7,>=1.2.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-widgets) (1.2.7)
# Requirement already satisfied: azure-common<2.0.0,>=1.1.12 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-widgets) (1.1.28)
# Requirement already satisfied: requests[socks]<3.0.0,>=2.19.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-widgets) (2.32.3)
# Requirement already satisfied: docker<8.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-widgets) (7.1.0)
# Requirement already satisfied: azure-mgmt-authorization<5,>=0.40.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-widgets) (4.0.0)
# Requirement already satisfied: jsonpickle<4.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-widgets) (3.2.2)
# Requirement already satisfied: knack<0.12.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-widgets) (0.11.0)
# Requirement already satisfied: urllib3<3.0.0,>1.26.17 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-widgets) (1.26.19)
# Requirement already satisfied: ndg-httpsclient<=0.5.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-widgets) (0.5.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.7.3 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-widgets) (2.9.0.post0)
# Requirement already satisfied: pkginfo in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-widgets) (1.11.1)
# Requirement already satisfied: paramiko<4.0.0,>=2.0.8 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-widgets) (3.4.0)
# Requirement already satisfied: SecretStorage<4.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-widgets) (3.3.3)
# Requirement already satisfied: azure-mgmt-storage<=22.0.0,>=16.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-widgets) (21.2.0)
# Requirement already satisfied: azure-mgmt-network<=26.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-widgets) (25.1.0)
# Requirement already satisfied: pytz in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-widgets) (2022.5)
# Requirement already satisfied: azure-mgmt-keyvault<11.0.0,>=0.40.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-widgets) (10.3.0)
# Requirement already satisfied: pyopenssl<25.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-widgets) (23.0.0)
# Requirement already satisfied: msal<2.0.0,>=1.15.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-widgets) (1.30.0)
# Requirement already satisfied: applicationinsights in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-telemetry~=1.57.0->azureml-widgets) (0.11.10)
# Requirement already satisfied: traitlets>=4.3.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (5.14.3)
# Requirement already satisfied: ipython>=4.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (8.27.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (1.1.9)
# Requirement already satisfied: ipykernel>=4.5.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (6.29.5)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (3.6.8)
# Requirement already satisfied: MarkupSafe>=2.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from jinja2<4.0->azureml-widgets) (2.1.5)
# Requirement already satisfied: typing-extensions>=4.6.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azure-core<2.0.0,>=1.23.1->azure-storage-blob>=12.6.0->azureml-widgets) (4.12.2)
# Requirement already satisfied: six>=1.11.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azure-core<2.0.0,>=1.23.1->azure-storage-blob>=12.6.0->azureml-widgets) (1.16.0)
# Requirement already satisfied: azure-mgmt-core<2.0.0,>=1.3.2 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azure-mgmt-authorization<5,>=0.40.0->azureml-core~=1.57.0->azureml-widgets) (1.4.0)
# Requirement already satisfied: isodate<1.0.0,>=0.6.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azure-mgmt-authorization<5,>=0.40.0->azureml-core~=1.57.0->azureml-widgets) (0.6.1)
# Requirement already satisfied: cffi>=1.12 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from cryptography>=2.1.4->azure-storage-blob>=12.6.0->azureml-widgets) (1.16.0)
# Requirement already satisfied: debugpy>=1.6.5 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (1.8.5)
# Requirement already satisfied: matplotlib-inline>=0.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.1.7)
# Requirement already satisfied: psutil in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (5.9.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (5.7.2)
# Requirement already satisfied: comm>=0.1.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.2.2)
# Requirement already satisfied: nest-asyncio in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (1.6.0)
# Requirement already satisfied: tornado>=6.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (6.4.1)
# Requirement already satisfied: pyzmq>=24 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (26.2.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (7.4.9)
# Requirement already satisfied: pygments>=2.4.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (2.18.0)
# Requirement already satisfied: decorator in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.17.2)
# Requirement already satisfied: stack-data in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (4.9.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (3.0.47)
# Requirement already satisfied: exceptiongroup in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (1.2.2)
# Requirement already satisfied: tabulate in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from knack<0.12.0->azureml-core~=1.57.0->azureml-widgets) (0.9.0)
# Requirement already satisfied: pyyaml in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from knack<0.12.0->azureml-core~=1.57.0->azureml-widgets) (6.0.1)
# Requirement already satisfied: portalocker<3,>=1.4 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from msal-extensions<=2.0.0,>=0.3.0->azureml-core~=1.57.0->azureml-widgets) (2.10.1)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from msrest>=0.6.21->azure-storage-blob>=12.6.0->azureml-widgets) (2024.8.30)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from msrest>=0.6.21->azure-storage-blob>=12.6.0->azureml-widgets) (2.0.0)
# Requirement already satisfied: pyasn1>=0.1.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ndg-httpsclient<=0.5.1->azureml-core~=1.57.0->azureml-widgets) (0.6.0)
# Requirement already satisfied: bcrypt>=3.2 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from paramiko<4.0.0,>=2.0.8->azureml-core~=1.57.0->azureml-widgets) (4.2.0)
# Requirement already satisfied: pynacl>=1.5 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from paramiko<4.0.0,>=2.0.8->azureml-core~=1.57.0->azureml-widgets) (1.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from requests[socks]<3.0.0,>=2.19.1->azureml-core~=1.57.0->azureml-widgets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from requests[socks]<3.0.0,>=2.19.1->azureml-core~=1.57.0->azureml-widgets) (3.7)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from requests[socks]<3.0.0,>=2.19.1->azureml-core~=1.57.0->azureml-widgets) (1.7.1)
# Requirement already satisfied: jeepney>=0.6 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from SecretStorage<4.0.0->azureml-core~=1.57.0->azureml-widgets) (0.8.0)
# Requirement already satisfied: notebook>=4.4.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (6.5.7)
# Requirement already satisfied: backports.weakref in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from backports.tempfile->azureml-core~=1.57.0->azureml-widgets) (1.0.post1)
# Requirement already satisfied: pycparser in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob>=12.6.0->azureml-widgets) (2.22)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.7.1)
# Requirement already satisfied: entrypoints in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (4.3.6)
# Requirement already satisfied: prometheus-client in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.21.0)
# Requirement already satisfied: nbformat in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (7.16.4)
# Requirement already satisfied: Send2Trash>=1.8.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.18.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (1.1.0)
# Requirement already satisfied: argon2-cffi in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (23.1.0)
# Requirement already satisfied: ptyprocess>=0.5 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.7.0)
# Requirement already satisfied: wcwidth in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=4.0.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.2.13)
# Requirement already satisfied: oauthlib>=3.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.21->azure-storage-blob>=12.6.0->azureml-widgets) (3.2.2)
# Requirement already satisfied: executing>=1.2.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (2.1.0)
# Requirement already satisfied: pure-eval in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.2.3)
# Requirement already satisfied: asttokens>=2.1.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (2.4.1)
# Requirement already satisfied: notebook-shim>=0.2.3 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.2.4)
# Requirement already satisfied: nbclient>=0.5.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.10.0)
# Requirement already satisfied: beautifulsoup4 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (4.12.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (1.5.1)
# Requirement already satisfied: defusedxml in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.7.1)
# Requirement already satisfied: tinycss2 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (1.3.0)
# Requirement already satisfied: bleach!=5.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (6.1.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (3.0.2)
# Requirement already satisfied: jupyterlab-pygments in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.3.0)
# Requirement already satisfied: jsonschema>=2.6 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (4.23.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (2.20.0)
# Requirement already satisfied: argon2-cffi-bindings in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (21.2.0)
# Requirement already satisfied: webencodings in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from bleach!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.5.1)
# Requirement already satisfied: referencing>=0.28.4 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.35.1)
# Requirement already satisfied: attrs>=22.2.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (2023.12.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.19.1)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (2.14.2)
# Requirement already satisfied: soupsieve>1.2 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (2.5)
# Requirement already satisfied: websocket-client>=1.7 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (1.8.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.5.3)
# Requirement already satisfied: anyio>=3.1.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (4.6.0)
# Requirement already satisfied: overrides>=5.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (7.7.0)
# Requirement already satisfied: sniffio>=1.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (1.3.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (2.0.7)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.1.1)
# Requirement already satisfied: rfc3339-validator in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.1.4)
# Requirement already satisfied: fqdn in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (1.5.1)
# Requirement already satisfied: jsonpointer>1.13 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (3.0.0)
# Requirement already satisfied: isoduration in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (20.11.0)
# Requirement already satisfied: uri-template in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (24.8.0)
# Requirement already satisfied: arrow>=0.15.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from isoduration->jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from arrow>=0.15.0->isoduration->jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (2.9.0.20240906)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade jinja2
# Out:
# Requirement already satisfied: jinja2 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (3.1.4)
# Collecting jinja2
#   Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from jinja2) (2.1.5)
# Installing collected packages: jinja2
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 3.1.4
#     Uninstalling Jinja2-3.1.4:
#       Successfully uninstalled Jinja2-3.1.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyterlab-topbar 0.6.1 requires jupyterlab~=3.0, but you have jupyterlab 4.0.11 which is incompatible.
# jupyterlab-system-monitor 0.8.0 requires jupyterlab~=3.0, but you have jupyterlab 4.0.11 which is incompatible.
# dask-sql 2024.5.0 requires dask[dataframe]>=2024.4.1, but you have dask 2023.2.0 which is incompatible.
# dask-sql 2024.5.0 requires distributed>=2024.4.1, but you have distributed 2023.2.0 which is incompatible.
# dask-sql 2024.5.0 requires pandas>=1.4.0, but you have pandas 1.3.5 which is incompatible.
# azureml-defaults 1.57.0 requires azureml-inference-server-http~=1.2.1, but you have azureml-inference-server-http 1.4.0 which is incompatible.
# azureml-automl-dnn-nlp 1.57.0 requires torch==1.13.1, but you have torch 2.4.1 which is incompatible.
# Successfully installed jinja2-3.1.6
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install azureml-train
# Out:
# Requirement already satisfied: azureml-train in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (1.57.0)
# Requirement already satisfied: azureml-train-core~=1.57.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-train) (1.57.0)
# Requirement already satisfied: azureml-telemetry~=1.57.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-train-core~=1.57.0->azureml-train) (1.57.0)
# Requirement already satisfied: azureml-core~=1.57.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-train-core~=1.57.0->azureml-train) (1.57.0)
# Requirement already satisfied: azureml-train-restclients-hyperdrive~=1.57.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-train-core~=1.57.0->azureml-train) (1.57.0)
# Requirement already satisfied: packaging<=25.0,>=20.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (24.1)
# Requirement already satisfied: azure-mgmt-resource<=24.0.0,>=15.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (23.1.1)
# Requirement already satisfied: msal-extensions<=2.0.0,>=0.3.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (1.2.0)
# Requirement already satisfied: pkginfo in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (1.11.1)
# Requirement already satisfied: knack<0.12.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (0.11.0)
# Requirement already satisfied: pathspec<1.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (0.12.1)
# Requirement already satisfied: azure-mgmt-keyvault<11.0.0,>=0.40.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (10.3.0)
# Requirement already satisfied: ndg-httpsclient<=0.5.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (0.5.1)
# Requirement already satisfied: msal<2.0.0,>=1.15.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (1.30.0)
# Requirement already satisfied: azure-mgmt-storage<=22.0.0,>=16.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (21.2.0)
# Requirement already satisfied: azure-mgmt-network<=26.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (25.1.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.7.3 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (2.9.0.post0)
# Requirement already satisfied: azure-core<2.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (1.30.2)
# Requirement already satisfied: paramiko<4.0.0,>=2.0.8 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (3.4.0)
# Requirement already satisfied: azure-common<2.0.0,>=1.1.12 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (1.1.28)
# Requirement already satisfied: SecretStorage<4.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (3.3.3)
# Requirement already satisfied: PyJWT<3.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (2.4.0)
# Requirement already satisfied: contextlib2<22.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (21.6.0)
# Requirement already satisfied: msrest<=0.7.1,>=0.5.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (0.7.1)
# Requirement already satisfied: pytz in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (2022.5)
# Requirement already satisfied: azure-mgmt-authorization<5,>=0.40.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (4.0.0)
# Requirement already satisfied: backports.tempfile in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (1.0)
# Requirement already satisfied: requests[socks]<3.0.0,>=2.19.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (2.32.3)
# Requirement already satisfied: urllib3<3.0.0,>1.26.17 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (1.26.19)
# Requirement already satisfied: jsonpickle<4.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (3.2.2)
# Requirement already satisfied: azure-mgmt-containerregistry<11,>=8.2.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (10.3.0)
# Requirement already satisfied: adal<=1.2.7,>=1.2.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (1.2.7)
# Requirement already satisfied: msrestazure<=0.7,>=0.4.33 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (0.6.4.post1)
# Requirement already satisfied: azure-graphrbac<1.0.0,>=0.40.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (0.60.0)
# Requirement already satisfied: humanfriendly<11.0,>=4.7 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (10.0)
# Requirement already satisfied: pyopenssl<25.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (23.0.0)
# Requirement already satisfied: jmespath<2.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (0.10.0)
# Requirement already satisfied: argcomplete<4 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (3.3.0)
# Requirement already satisfied: docker<8.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (7.1.0)
# Requirement already satisfied: applicationinsights in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-telemetry~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (0.11.10)
# Requirement already satisfied: cryptography>=1.1.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from adal<=1.2.7,>=1.2.0->azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (38.0.4)
# Requirement already satisfied: six>=1.11.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azure-core<2.0.0->azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (1.16.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azure-core<2.0.0->azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (4.12.2)
# Requirement already satisfied: isodate<1.0.0,>=0.6.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azure-mgmt-authorization<5,>=0.40.0->azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (0.6.1)
# Requirement already satisfied: azure-mgmt-core<2.0.0,>=1.3.2 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azure-mgmt-authorization<5,>=0.40.0->azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (1.4.0)
# Requirement already satisfied: pyyaml in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from knack<0.12.0->azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (6.0.1)
# Requirement already satisfied: pygments in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from knack<0.12.0->azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (2.18.0)
# Requirement already satisfied: tabulate in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from knack<0.12.0->azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (0.9.0)
# Requirement already satisfied: portalocker<3,>=1.4 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from msal-extensions<=2.0.0,>=0.3.0->azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (2.10.1)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from msrest<=0.7.1,>=0.5.1->azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (2024.8.30)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from msrest<=0.7.1,>=0.5.1->azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (2.0.0)
# Requirement already satisfied: pyasn1>=0.1.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ndg-httpsclient<=0.5.1->azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (0.6.0)
# Requirement already satisfied: pynacl>=1.5 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from paramiko<4.0.0,>=2.0.8->azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (1.5.0)
# Requirement already satisfied: bcrypt>=3.2 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from paramiko<4.0.0,>=2.0.8->azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (4.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from requests[socks]<3.0.0,>=2.19.1->azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from requests[socks]<3.0.0,>=2.19.1->azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (3.7)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from requests[socks]<3.0.0,>=2.19.1->azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (1.7.1)
# Requirement already satisfied: jeepney>=0.6 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from SecretStorage<4.0.0->azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (0.8.0)
# Requirement already satisfied: backports.weakref in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from backports.tempfile->azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (1.0.post1)
# Requirement already satisfied: cffi>=1.12 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from cryptography>=1.1.0->adal<=1.2.7,>=1.2.0->azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (1.16.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from requests-oauthlib>=0.5.0->msrest<=0.7.1,>=0.5.1->azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (3.2.2)
# Requirement already satisfied: pycparser in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=1.1.0->adal<=1.2.7,>=1.2.0->azureml-core~=1.57.0->azureml-train-core~=1.57.0->azureml-train) (2.22)
# Note: you may need to restart the kernel to use updated packages.

# %%
from azureml.widgets import RunDetails

# %%
from azureml.widgets import RunDetails
from azureml.train.sklearn import SKLearn
from azureml.train.hyperdrive.run import PrimaryMetricGoal
from azureml.train.hyperdrive.policy import BanditPolicy
from azureml.train.hyperdrive.sampling import RandomParameterSampling
from azureml.train.hyperdrive.runconfig import HyperDriveConfig
from azureml.train.hyperdrive.parameter_expressions import choice, uniform
from azureml.core import Environment, ScriptRunConfig
import os

# %%
# Specify parameter sampler
#ps = ### YOUR CODE HERE ###

ps = RandomParameterSampling(
    {
        '--C': uniform(0.01, 0.1),
        '--max_iter': choice([50, 100, 200])

    }
)


# Specify a Policy
# policy = ### YOUR CODE HERE ###
policy = BanditPolicy(evaluation_interval=2, slack_factor=0.1)

if "training" not in os.listdir():
    os.mkdir("./training")

# Setup environment for your training run
sklearn_env = Environment.from_conda_specification(name='sklearn-env', file_path='conda_dependencies.yml')

# Create a ScriptRunConfig Object to specify the configuration details of your training job
# src = ### YOUR CODE HERE ###
# passing parameters to the training script

src = ScriptRunConfig(
    source_directory=script_folder,
    script="train.py",
    compute_target="c003",  # Replace with your compute target
    environment=sklearn_env,
    arguments=[
        "--C", 0.1,
        "--max_iter", 200,
        "--test_train_ratio", 0.25
    ]
)

# Create a HyperDriveConfig using the src object, hyperparameter sampler, and policy.
# hyperdrive_config = ### YOUR CODE HERE ###

hyperdrive_config =HyperDriveConfig(run_config=src, 
                             hyperparameter_sampling=ps,
                             policy=policy,
                             primary_metric_name='Accuracy', 
                             primary_metric_goal=PrimaryMetricGoal.MAXIMIZE, 
                             max_total_runs=10,
                             max_concurrent_runs=2)

# %%
# Submit your hyperdrive run to the experiment and show run details with the widget.

### YOUR CODE HERE ###

hyperdrive_run = exp.submit(hyperdrive_config)
RunDetails(hyperdrive_run).show()
print("Submitted HyperDrive run id:", hyperdrive_run.id)
hyperdrive_run.wait_for_completion(show_output=True)
assert(hyperdrive_run.get_status() == "Completed")
# Out:
# 2025-03-26 21:26:15.080788: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-03-26 21:26:15.234672: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-03-26 21:26:15.281353: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-26 21:26:15.599906: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-03-26 21:26:18.043596: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# _HyperDriveWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO'…
# Submitted HyperDrive run id: HD_eea178ad-0681-4753-a6db-b384727204e5
# RunId: HD_eea178ad-0681-4753-a6db-b384727204e5
# Web View: https://ml.azure.com/runs/HD_eea178ad-0681-4753-a6db-b384727204e5?wsid=/subscriptions/d990bb6c-7849-4109-9dd7-6cafa051c8ae/resourcegroups/mlcloud/workspaces/mlcloud&tid=4c460090-f86f-4a64-9b48-ed4b89bbef7b
#
# Streaming azureml-logs/hyperdrive.txt
# =====================================
#
# [2025-03-26T21:26:07.8789891Z][GENERATOR][DEBUG]Sampled 2 jobs from search space
# [2025-03-26T21:26:08.2236687Z][SCHEDULER][INFO]Scheduling job, id='HD_eea178ad-0681-4753-a6db-b384727204e5_0'
# [2025-03-26T21:26:08.3054536Z][SCHEDULER][INFO]Scheduling job, id='HD_eea178ad-0681-4753-a6db-b384727204e5_1'
# [2025-03-26T21:26:08.6658152Z][SCHEDULER][INFO]Successfully scheduled a job. Id='HD_eea178ad-0681-4753-a6db-b384727204e5_1'
# [2025-03-26T21:26:08.7636397Z][SCHEDULER][INFO]Successfully scheduled a job. Id='HD_eea178ad-0681-4753-a6db-b384727204e5_0'
# [2025-03-26T21:28:43.8815001Z][GENERATOR][DEBUG]Sampled 2 jobs from search space
# [2025-03-26T21:28:44.2585638Z][SCHEDULER][INFO]Scheduling job, id='HD_eea178ad-0681-4753-a6db-b384727204e5_2'
# [2025-03-26T21:28:44.3935508Z][SCHEDULER][INFO]Scheduling job, id='HD_eea178ad-0681-4753-a6db-b384727204e5_3'
# [2025-03-26T21:28:44.6320639Z][SCHEDULER][INFO]Successfully scheduled a job. Id='HD_eea178ad-0681-4753-a6db-b384727204e5_3'
# [2025-03-26T21:28:44.7134685Z][SCHEDULER][INFO]Successfully scheduled a job. Id='HD_eea178ad-0681-4753-a6db-b384727204e5_2'
# [2025-03-26T21:29:45.9209245Z][GENERATOR][DEBUG]Sampled 1 jobs from search space
# [2025-03-26T21:29:46.2179930Z][SCHEDULER][INFO]Scheduling job, id='HD_eea178ad-0681-4753-a6db-b384727204e5_4'
# [2025-03-26T21:29:46.5106661Z][SCHEDULER][INFO]Successfully scheduled a job. Id='HD_eea178ad-0681-4753-a6db-b384727204e5_4'
# [2025-03-26T21:30:17.4482377Z][GENERATOR][DEBUG]Sampled 1 jobs from search space
# [2025-03-26T21:30:17.7695544Z][SCHEDULER][INFO]Scheduling job, id='HD_eea178ad-0681-4753-a6db-b384727204e5_5'
# [2025-03-26T21:30:18.0277043Z][SCHEDULER][INFO]Successfully scheduled a job. Id='HD_eea178ad-0681-4753-a6db-b384727204e5_5'
# [2025-03-26T21:30:48.9760034Z][GENERATOR][DEBUG]Sampled 1 jobs from search space
# [2025-03-26T21:30:49.1217371Z][SCHEDULER][INFO]Scheduling job, id='HD_eea178ad-0681-4753-a6db-b384727204e5_6'
# [2025-03-26T21:30:49.4100860Z][SCHEDULER][INFO]Successfully scheduled a job. Id='HD_eea178ad-0681-4753-a6db-b384727204e5_6'
# [2025-03-26T21:31:20.5942816Z][GENERATOR][DEBUG]Sampled 1 jobs from search space
# [2025-03-26T21:31:20.8190182Z][SCHEDULER][INFO]Scheduling job, id='HD_eea178ad-0681-4753-a6db-b384727204e5_7'
# [2025-03-26T21:31:21.1007658Z][SCHEDULER][INFO]Successfully scheduled a job. Id='HD_eea178ad-0681-4753-a6db-b384727204e5_7'
# [2025-03-26T21:31:52.1930197Z][GENERATOR][DEBUG]Sampled 1 jobs from search space
# [2025-03-26T21:31:52.4785367Z][SCHEDULER][INFO]Scheduling job, id='HD_eea178ad-0681-4753-a6db-b384727204e5_8'
# [2025-03-26T21:31:55.2550720Z][SCHEDULER][INFO]Successfully scheduled a job. Id='HD_eea178ad-0681-4753-a6db-b384727204e5_8'
# [2025-03-26T21:32:24.0283156Z][GENERATOR][DEBUG]Sampled 1 jobs from search space
# [2025-03-26T21:32:24.2233044Z][SCHEDULER][INFO]Scheduling job, id='HD_eea178ad-0681-4753-a6db-b384727204e5_9'
# [2025-03-26T21:32:24.4908457Z][SCHEDULER][INFO]Successfully scheduled a job. Id='HD_eea178ad-0681-4753-a6db-b384727204e5_9'
# [2025-03-26T21:32:54.3425689Z][GENERATOR][DEBUG]Setting all jobs generated as True, reason : Max number of jobs reached
# [2025-03-26T21:34:10.7822047Z][CONTROLLER][INFO]Changing Run Status from Running to Completed
#
# Execution Summary
# =================
# RunId: HD_eea178ad-0681-4753-a6db-b384727204e5
# Web View: https://ml.azure.com/runs/HD_eea178ad-0681-4753-a6db-b384727204e5?wsid=/subscriptions/d990bb6c-7849-4109-9dd7-6cafa051c8ae/resourcegroups/mlcloud/workspaces/mlcloud&tid=4c460090-f86f-4a64-9b48-ed4b89bbef7b

# %%
  # !pip show azureml-widgets
  # !pip show azureml-core
# Out:
# Name: azureml-widgets
# Version: 1.57.0
# Summary: Provides fully supported, with interactivity, async auto-updates, and non-blocking cell execution.
# Home-page: https://docs.microsoft.com/python/api/overview/azure/ml/?view=azure-ml-py
# Author: Microsoft Corp
# Author-email:
# License: https://aka.ms/azureml-sdk-license
# Location: /anaconda/envs/azureml_py38/lib/python3.10/site-packages
# Requires: azure-storage-blob, azureml-core, azureml-telemetry, ipywidgets, jinja2
# Required-by:
# Name: azureml-core
# Version: 1.57.0
# Summary: Azure Machine Learning core packages, modules, and classes
# Home-page: https://docs.microsoft.com/python/api/overview/azure/ml/?view=azure-ml-py
# Author: Microsoft Corp
# Author-email:
# License: https://aka.ms/azureml-sdk-license
# Location: /anaconda/envs/azureml_py38/lib/python3.10/site-packages
# Requires: adal, argcomplete, azure-common, azure-core, azure-graphrbac, azure-mgmt-authorization, azure-mgmt-containerregistry, azure-mgmt-keyvault, azure-mgmt-network, azure-mgmt-resource, azure-mgmt-storage, backports.tempfile, contextlib2, docker, humanfriendly, jmespath, jsonpickle, knack, msal, msal-extensions, msrest, msrestazure, ndg-httpsclient, packaging, paramiko, pathspec, pkginfo, PyJWT, pyopenssl, python-dateutil, pytz, requests, SecretStorage, urllib3
# Required-by: azureml-accel-models, azureml-automl-dnn-nlp, azureml-cli-common, azureml-contrib-dataset, azureml-contrib-fairness, azureml-contrib-notebook, azureml-contrib-pipeline-steps, azureml-contrib-reinforcementlearning, azureml-contrib-server, azureml-datadrift, azureml-defaults, azureml-interpret, azureml-opendatasets, azureml-pipeline-core, azureml-responsibleai, azureml-sdk, azureml-telemetry, azureml-tensorboard, azureml-train-automl-client, azureml-train-automl-runtime, azureml-train-core, azureml-widgets
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# ###

# %% [markdown]
# ### Retrieve the best run

# %%
import joblib
# Get your best run and save the model from that run.

### YOUR CODE HERE ###

best_run = hyperdrive_run.get_best_run_by_primary_metric()
print("Best Run ID:", best_run.id)
print("Best Run Metrics:", best_run.get_metrics())
# Out:
# Best Run ID: HD_06e9be6d-7868-4a9e-9c4a-fb708722726f_0
# Best Run Metrics: {'Regularization Strength:': 0.0220308670897337, 'Max iterations:': 100, 'Accuracy': 0.9093226511289147}

# %%
# Download the model files
from azureml.core import Model

best_run.download_file(name="outputs/model.pkl", output_file_path="best_model.pkl") #adjust path if needed.

# Register the model
model = Model.register(
    workspace=ws,
    model_path="best_model.pkl",  # Local path to the downloaded model
    model_name="best-logistic-regression-model",
    tags={"Training context": "HyperDrive"},
    description="Best Logistic Regression Model from Optimizing an ML Pipeline in Azure",
)

print("Registered Model ID:", model.id)
# Out:
# Registering model best-logistic-regression-model
# Registered Model ID: best-logistic-regression-model:2

# %% [markdown]
# ### Import data to a Dataset using the SDK.

# %%
from azureml.data.dataset_factory import TabularDatasetFactory

# Create TabularDataset using TabularDatasetFactory
# Data is available at: 
# "https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv"

### YOUR CODE HERE ###

data_url = 'https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv' 
dataset = TabularDatasetFactory.from_delimited_files(data_url)
df = dataset.to_pandas_dataframe()
print(df.head())  # Display the first few rows of the dataframe
# Out:
# {'infer_column_types': 'False', 'activity': 'to_pandas_dataframe'}
# {'infer_column_types': 'False', 'activity': 'to_pandas_dataframe', 'activityApp': 'TabularDataset'}
#    age          job  marital    education  default housing loan    contact  \
# 0   57   technician  married  high.school       no      no  yes   cellular
# 1   55      unknown  married      unknown  unknown     yes   no  telephone
# 2   33  blue-collar  married     basic.9y       no      no   no   cellular
# 3   36       admin.  married  high.school       no      no   no  telephone
# 4   27    housemaid  married  high.school       no     yes   no   cellular
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         1      failure         -1.8
# 1   may         thu  ...         2    999         0  nonexistent          1.1
# 2   may         fri  ...         1    999         1      failure         -1.8
# 3   jun         fri  ...         4    999         0  nonexistent          1.4
# 4   jul         fri  ...         2    999         0  nonexistent          1.4
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          92.893          -46.2      1.299       5099.1  no
# 1          93.994          -36.4      4.860       5191.0  no
# 2          92.893          -46.2      1.313       5099.1  no
# 3          94.465          -41.8      4.967       5228.1  no
# 4          93.918          -42.7      4.963       5228.1  no
#
# [5 rows x 21 columns]

# %%
from scripts.train import clean_data
# Use the clean_data function to clean your data.
X,y = clean_data(dataset)
# Out:
# {'infer_column_types': 'False', 'activity': 'to_pandas_dataframe'}
# {'infer_column_types': 'False', 'activity': 'to_pandas_dataframe', 'activityApp': 'TabularDataset'}

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32950 entries, 0 to 32949
# Data columns (total 39 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   age                            32950 non-null  int64
#  1   marital                        32950 non-null  int64
#  2   default                        32950 non-null  int64
#  3   housing                        32950 non-null  int64
#  4   loan                           32950 non-null  int64
#  5   month                          32950 non-null  int64
#  6   day_of_week                    32950 non-null  int64
#  7   duration                       32950 non-null  int64
#  8   campaign                       32950 non-null  int64
#  9   pdays                          32950 non-null  int64
#  10  previous                       32950 non-null  int64
#  11  poutcome                       32950 non-null  int64
#  12  emp.var.rate                   32950 non-null  float64
#  13  cons.price.idx                 32950 non-null  float64
#  14  cons.conf.idx                  32950 non-null  float64
#  15  euribor3m                      32950 non-null  float64
#  16  nr.employed                    32950 non-null  float64
#  17  job_admin.                     32950 non-null  uint8
#  18  job_blue-collar                32950 non-null  uint8
#  19  job_entrepreneur               32950 non-null  uint8
#  20  job_housemaid                  32950 non-null  uint8
#  21  job_management                 32950 non-null  uint8
#  22  job_retired                    32950 non-null  uint8
#  23  job_self-employed              32950 non-null  uint8
#  24  job_services                   32950 non-null  uint8
#  25  job_student                    32950 non-null  uint8
#  26  job_technician                 32950 non-null  uint8
#  27  job_unemployed                 32950 non-null  uint8
#  28  job_unknown                    32950 non-null  uint8
#  29  contact_cellular               32950 non-null  uint8
#  30  contact_telephone              32950 non-null  uint8
#  31  education_basic.4y             32950 non-null  uint8
#  32  education_basic.6y             32950 non-null  uint8
#  33  education_basic.9y             32950 non-null  uint8
#  34  education_high.school          32950 non-null  uint8
#  35  education_illiterate           32950 non-null  uint8
#  36  education_professional.course  32950 non-null  uint8
#  37  education_university.degree    32950 non-null  uint8
#  38  education_unknown              32950 non-null  uint8
# dtypes: float64(5), int64(12), uint8(22)
# memory usage: 6.2 MB

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: y, dtype: int64

# %%
import pandas as pd
from azureml.core.dataset import Dataset

# %%
combined_df = pd.concat([X, y], axis=1)

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32950 entries, 0 to 32949
# Data columns (total 40 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   age                            32950 non-null  int64
#  1   marital                        32950 non-null  int64
#  2   default                        32950 non-null  int64
#  3   housing                        32950 non-null  int64
#  4   loan                           32950 non-null  int64
#  5   month                          32950 non-null  int64
#  6   day_of_week                    32950 non-null  int64
#  7   duration                       32950 non-null  int64
#  8   campaign                       32950 non-null  int64
#  9   pdays                          32950 non-null  int64
#  10  previous                       32950 non-null  int64
#  11  poutcome                       32950 non-null  int64
#  12  emp.var.rate                   32950 non-null  float64
#  13  cons.price.idx                 32950 non-null  float64
#  14  cons.conf.idx                  32950 non-null  float64
#  15  euribor3m                      32950 non-null  float64
#  16  nr.employed                    32950 non-null  float64
#  17  job_admin.                     32950 non-null  uint8
#  18  job_blue-collar                32950 non-null  uint8
#  19  job_entrepreneur               32950 non-null  uint8
#  20  job_housemaid                  32950 non-null  uint8
#  21  job_management                 32950 non-null  uint8
#  22  job_retired                    32950 non-null  uint8
#  23  job_self-employed              32950 non-null  uint8
#  24  job_services                   32950 non-null  uint8
#  25  job_student                    32950 non-null  uint8
#  26  job_technician                 32950 non-null  uint8
#  27  job_unemployed                 32950 non-null  uint8
#  28  job_unknown                    32950 non-null  uint8
#  29  contact_cellular               32950 non-null  uint8
#  30  contact_telephone              32950 non-null  uint8
#  31  education_basic.4y             32950 non-null  uint8
#  32  education_basic.6y             32950 non-null  uint8
#  33  education_basic.9y             32950 non-null  uint8
#  34  education_high.school          32950 non-null  uint8
#  35  education_illiterate           32950 non-null  uint8
#  36  education_professional.course  32950 non-null  uint8
#  37  education_university.degree    32950 non-null  uint8
#  38  education_unknown              32950 non-null  uint8
#  39  y                              32950 non-null  int64
# dtypes: float64(5), int64(13), uint8(22)
# memory usage: 6.5 MB

# %%
from sklearn.model_selection import train_test_split

train_df, test_df = train_test_split(combined_df, test_size=0.25, random_state=42)

# %%
print(train_df.shape, test_df.shape)
# Out:
# (24712, 40) (8238, 40)

# %%
training_dataset = Dataset.Tabular.register_pandas_dataframe(
    dataframe=train_df,
    target=ws.get_default_datastore(),
    name='training_data',
    show_progress=True
)
# Out:
# Validating arguments.
# Arguments validated.
# Column header contains '.' This period will be translated to '_' as we write the data out to parquet files: 'emp.var.rate' -> 'emp_var_rate'
# Column header contains '.' This period will be translated to '_' as we write the data out to parquet files: 'cons.price.idx' -> 'cons_price_idx'
# Column header contains '.' This period will be translated to '_' as we write the data out to parquet files: 'cons.conf.idx' -> 'cons_conf_idx'
# Column header contains '.' This period will be translated to '_' as we write the data out to parquet files: 'nr.employed' -> 'nr_employed'
# Column header contains '.' This period will be translated to '_' as we write the data out to parquet files: 'job_admin.' -> 'job_admin_'
# Column header contains '.' This period will be translated to '_' as we write the data out to parquet files: 'education_basic.4y' -> 'education_basic_4y'
# Column header contains '.' This period will be translated to '_' as we write the data out to parquet files: 'education_basic.6y' -> 'education_basic_6y'
# Column header contains '.' This period will be translated to '_' as we write the data out to parquet files: 'education_basic.9y' -> 'education_basic_9y'
# Column header contains '.' This period will be translated to '_' as we write the data out to parquet files: 'education_high.school' -> 'education_high_school'
# Column header contains '.' This period will be translated to '_' as we write the data out to parquet files: 'education_professional.course' -> 'education_professional_course'
# Column header contains '.' This period will be translated to '_' as we write the data out to parquet files: 'education_university.degree' -> 'education_university_degree'
# Validating arguments.
# Arguments validated.
# 'overwrite' is set to True. Any file already present in the target will be overwritten.
# Uploading files from '/tmp/tmprnzcsc4t' to 'managed-dataset/2b1f91b6-af52-4b4b-85bf-8dab8bc496a7/'
# Copying 1 files with concurrency set to 1
# Copied /tmp/tmprnzcsc4t/dataframe.parquet, file 1 out of 1. Destination path: https://mlcloud3305625934.blob.core.windows.net/azureml-blobstore-41a1d4be-78dc-4d1a-9310-94e0ca65ccba/managed-dataset/2b1f91b6-af52-4b4b-85bf-8dab8bc496a7/dataframe.parquet
# Files copied=1, skipped=0, failed=0
# Successfully uploaded file to datastore.
# Creating and registering a new dataset.
# Successfully created and registered a new dataset.

# %%
val_dataset = Dataset.Tabular.register_pandas_dataframe(
    dataframe=test_df,
    target=ws.get_default_datastore(),
    name='val_data',
    show_progress=True
)
# Out:
# Validating arguments.
# Arguments validated.
# Column header contains '.' This period will be translated to '_' as we write the data out to parquet files: 'emp.var.rate' -> 'emp_var_rate'
# Column header contains '.' This period will be translated to '_' as we write the data out to parquet files: 'cons.price.idx' -> 'cons_price_idx'
# Column header contains '.' This period will be translated to '_' as we write the data out to parquet files: 'cons.conf.idx' -> 'cons_conf_idx'
# Column header contains '.' This period will be translated to '_' as we write the data out to parquet files: 'nr.employed' -> 'nr_employed'
# Column header contains '.' This period will be translated to '_' as we write the data out to parquet files: 'job_admin.' -> 'job_admin_'
# Column header contains '.' This period will be translated to '_' as we write the data out to parquet files: 'education_basic.4y' -> 'education_basic_4y'
# Column header contains '.' This period will be translated to '_' as we write the data out to parquet files: 'education_basic.6y' -> 'education_basic_6y'
# Column header contains '.' This period will be translated to '_' as we write the data out to parquet files: 'education_basic.9y' -> 'education_basic_9y'
# Column header contains '.' This period will be translated to '_' as we write the data out to parquet files: 'education_high.school' -> 'education_high_school'
# Column header contains '.' This period will be translated to '_' as we write the data out to parquet files: 'education_professional.course' -> 'education_professional_course'
# Column header contains '.' This period will be translated to '_' as we write the data out to parquet files: 'education_university.degree' -> 'education_university_degree'
# Validating arguments.
# Arguments validated.
# 'overwrite' is set to True. Any file already present in the target will be overwritten.
# Uploading files from '/tmp/tmp060ri03p' to 'managed-dataset/cd95a7ca-e9af-4f90-ae26-82eb772e9618/'
# Copying 1 files with concurrency set to 1
# Copied /tmp/tmp060ri03p/dataframe.parquet, file 1 out of 1. Destination path: https://mlcloud3305625934.blob.core.windows.net/azureml-blobstore-41a1d4be-78dc-4d1a-9310-94e0ca65ccba/managed-dataset/cd95a7ca-e9af-4f90-ae26-82eb772e9618/dataframe.parquet
# Successfully uploaded file to datastore.
# Creating and registering a new dataset.
# Files copied=1, skipped=0, failed=0
# Successfully created and registered a new dataset.

# %% [markdown]
# ### Create an AutoMLConfig for training.

# %%
from azureml.train.automl import AutoMLConfig

# Set parameters for AutoMLConfig
# NOTE: DO NOT CHANGE THE experiment_timeout_minutes PARAMETER OR YOUR INSTANCE WILL TIME OUT.
# If you wish to run the experiment longer, you will need to run this notebook in your own
# Azure tenant, which will incur personal costs.

automl_settings = {
    "experiment_timeout_minutes": 30,
    "enable_early_stopping": True,
    "iteration_timeout_minutes": 5,
    "max_concurrent_iterations": 4,
    "max_cores_per_iteration": -1,
    # "n_cross_validations": 2,
    "primary_metric": "accuracy",
    "featurization": "auto",
    "verbosity": logging.INFO,
    "enable_code_generation": True,
}

automl_config = AutoMLConfig(
    task="classification",
    debug_log="automl_errors.log",
    compute_target="c003",
    experiment_exit_score=0.9984,
    blocked_models=["KNN", "LinearSVM"],
    enable_onnx_compatible_models=True,
    training_data=training_dataset,
    label_column_name='y',
    validation_data=val_dataset,
    **automl_settings,
)

# %%
# Submit your automl run

### YOUR CODE HERE ###

remote_run = exp.submit(automl_config, show_output=False)
# Out:
# Submitting remote run.
# <table style="width:100%"><tr><th>Experiment</th><th>Id</th><th>Type</th><th>Status</th><th>Details Page</th><th>Docs Page</th></tr><tr><td>udacity-project</td><td>AutoML_e2c203f5-5606-4267-aa45-fc72d144b495</td><td>automl</td><td>NotStarted</td><td><a href="https://ml.azure.com/runs/AutoML_e2c203f5-5606-4267-aa45-fc72d144b495?wsid=/subscriptions/d990bb6c-7849-4109-9dd7-6cafa051c8ae/resourcegroups/mlcloud/workspaces/mlcloud&amp;tid=4c460090-f86f-4a64-9b48-ed4b89bbef7b" target="_blank" rel="noopener">Link to Azure Machine Learning studio</a></td><td><a href="https://docs.microsoft.com/en-us/python/api/overview/azure/ml/intro?view=azure-ml-py" target="_blank" rel="noopener">Link to Documentation</a></td></tr></table>

# %%
from azureml.widgets import RunDetails

RunDetails(remote_run).show()

# %%
# Wait for the remote run to complete
remote_run.wait_for_completion()
# Out:
# {'runId': 'AutoML_17a5bbfd-6834-40c0-9050-e180d725bdc9',
#  'target': 'c003',
#  'status': 'Completed',
#  'startTimeUtc': '2025-03-25T19:55:57.756536Z',
#  'endTimeUtc': '2025-03-25T20:26:17.158137Z',
#  'services': {},
#  'warnings': [{'source': 'JasmineService',
#    'message': 'No scores improved over last 10 iterations, so experiment stopped early. This early stopping behavior can be disabled by setting enable_early_stopping = False in AutoMLConfig for notebook/python SDK runs.'}],
#  'properties': {'num_iterations': '1000',
#   'training_type': 'TrainFull',
#   'acquisition_function': 'EI',
#   'primary_metric': 'accuracy',
#   'train_split': '0',
#   'acquisition_parameter': '0',
#   'num_cross_validation': None,
#   'target': 'c003',
#   'AMLSettingsJsonString': '{"path":null,"name":"udacity-project","subscription_id":"d990bb6c-7849-4109-9dd7-6cafa051c8ae","resource_group":"mlcloud","workspace_name":"mlcloud","region":"eastus2","compute_target":"c003","spark_service":null,"azure_service":"remote","many_models":false,"pipeline_fetch_max_batch_size":1,"enable_batch_run":true,"enable_parallel_run":false,"num_procs":null,"enable_run_restructure":false,"start_auxiliary_runs_before_parent_complete":false,"enable_code_generation":true,"force_curated_environment":false,"iterations":1000,"primary_metric":"accuracy","task_type":"classification","positive_label":null,"data_script":null,"test_size":0.0,"test_include_predictions_only":false,"validation_size":0.0,"n_cross_validations":null,"y_min":null,"y_max":null,"num_classes":null,"featurization":"auto","_ignore_package_version_incompatibilities":false,"is_timeseries":false,"max_cores_per_iteration":-1,"max_concurrent_iterations":4,"iteration_timeout_minutes":5,"mem_in_mb":null,"enforce_time_on_windows":false,"experiment_timeout_minutes":30,"experiment_exit_score":0.9984,"partition_column_names":null,"whitelist_models":null,"blacklist_algos":["KNN","LinearSVM","TensorFlowLinearClassifier","TensorFlowDNN"],"supported_models":["SGD","TabnetClassifier","TensorFlowDNN","MultinomialNaiveBayes","RandomForest","BernoulliNaiveBayes","SVM","KNN","XGBoostClassifier","DecisionTree","LinearSVM","GradientBoosting","LogisticRegression","AveragedPerceptronClassifier","ExtremeRandomTrees","LightGBM","TensorFlowLinearClassifier"],"private_models":[],"auto_blacklist":true,"blacklist_samples_reached":false,"exclude_nan_labels":true,"verbosity":20,"_debug_log":"azureml_automl.log","show_warnings":false,"model_explainability":true,"service_url":null,"sdk_url":null,"sdk_packages":null,"enable_onnx_compatible_models":true,"enable_split_onnx_featurizer_estimator_models":false,"vm_type":"Standard_D2_V2","telemetry_verbosity":20,"send_telemetry":true,"enable_dnn":false,"scenario":"AutoML","environment_label":null,"save_mlflow":false,"enable_categorical_indicators":false,"force_text_dnn":false,"enable_feature_sweeping":false,"enable_early_stopping":true,"early_stopping_n_iters":10,"arguments":null,"dataset_id":"cf1028a1-aed4-40b5-9d72-7ca15bb3e8fe","hyperdrive_config":null,"validation_dataset_id":"ca56fa1b-9ed1-441a-bf06-fd7b76c6081d","run_source":null,"metrics":null,"enable_metric_confidence":false,"enable_ensembling":true,"enable_stack_ensembling":false,"ensemble_iterations":15,"enable_tf":false,"enable_subsampling":null,"subsample_seed":null,"enable_nimbusml":false,"enable_streaming":false,"force_streaming":false,"track_child_runs":true,"n_best_runs":1,"allowed_private_models":[],"label_column_name":"y","weight_column_name":null,"cv_split_column_names":null,"enable_local_managed":false,"_local_managed_run_id":null,"cost_mode":1,"lag_length":0,"metric_operation":"maximize","preprocess":true}',
#   'DataPrepJsonString': '{\\"training_data\\": {\\"datasetId\\": \\"cf1028a1-aed4-40b5-9d72-7ca15bb3e8fe\\"}, \\"validation_data\\": {\\"datasetId\\": \\"ca56fa1b-9ed1-441a-bf06-fd7b76c6081d\\"}, \\"datasets\\": 0}',
#   'EnableSubsampling': None,
#   'runTemplate': 'AutoML',
#   'azureml.runsource': 'automl',
#   'display_task_type': 'classification',
#   'dependencies_versions': '{"azureml-contrib-notebook": "1.57.0", "azureml-contrib-server": "1.57.0", "azureml-training-tabular": "1.57.0", "azureml-opendatasets": "1.57.0", "azureml-cli-common": "1.57.0", "azureml-automl-dnn-nlp": "1.57.0", "azureml-automl-runtime": "1.57.0", "azureml-dataprep-native": "41.0.0", "azureml-contrib-automl-pipeline-steps": "1.57.0", "azureml-dataprep-rslex": "2.22.2", "azureml-pipeline-steps": "1.57.0", "azureml-interpret": "1.57.0", "azureml-train": "1.57.0", "azureml-widgets": "1.57.0", "azureml-datadrift": "1.57.0", "azureml-inference-server-http": "1.4.0", "azureml-tensorboard": "1.57.0", "azureml-telemetry": "1.57.0", "azureml-train-automl-client": "1.57.0", "azureml-contrib-reinforcementlearning": "1.57.0", "azureml-sdk": "1.57.0", "azureml-contrib-pipeline-steps": "1.57.0", "azureml-core": "1.57.0", "azureml-train-core": "1.57.0", "azureml-train-restclients-hyperdrive": "1.57.0", "azureml-contrib-dataset": "1.57.0", "azureml-pipeline-core": "1.57.0", "azureml-dataprep": "5.1.6", "azureml-dataset-runtime": "1.57.0", "azureml-pipeline": "1.57.0", "azureml-fsspec": "1.3.1", "azureml-contrib-services": "1.57.0", "azureml-train-automl-runtime": "1.57.0", "azureml-mlflow": "1.57.0", "azureml-responsibleai": "1.57.0", "azureml-accel-models": "1.57.0", "azureml-automl-core": "1.57.0", "azureml-defaults": "1.57.0", "azureml-contrib-fairness": "1.57.0", "azureml-train-automl": "1.57.0"}',
#   '_aml_system_scenario_identification': 'Remote.Parent',
#   'ClientType': 'SDK',
#   'PlatformVersion': 'DPV1',
#   'environment_cpu_name': 'AzureML-ai-ml-automl',
#   'environment_cpu_label': '5',
#   'environment_gpu_name': 'AzureML-ai-ml-automl-gpu',
#   'environment_gpu_label': '5',
#   'root_attribution': 'automl',
#   'attribution': 'AutoML',
#   'Orchestrator': 'AutoML',
#   'CancelUri': 'https://eastus2.api.azureml.ms/jasmine/v1.0/subscriptions/d990bb6c-7849-4109-9dd7-6cafa051c8ae/resourceGroups/mlcloud/providers/Microsoft.MachineLearningServices/workspaces/mlcloud/experimentids/f6aa5ba5-d9f6-4144-84ce-f6341ef1447f/cancel/AutoML_17a5bbfd-6834-40c0-9050-e180d725bdc9',
#   'ClientSdkVersion': None,
#   'snapshotId': '00000000-0000-0000-0000-000000000000',
#   'SetupRunId': 'AutoML_17a5bbfd-6834-40c0-9050-e180d725bdc9_setup',
#   'SetupRunContainerId': 'dcid.AutoML_17a5bbfd-6834-40c0-9050-e180d725bdc9_setup',
#   'FeaturizationRunJsonPath': 'featurizer_container.json',
#   'FeaturizationRunId': 'AutoML_17a5bbfd-6834-40c0-9050-e180d725bdc9_featurize',
#   'ProblemInfoJsonString': '{"dataset_num_categorical": 0, "is_sparse": true, "subsampling": false, "has_extra_col": true, "dataset_classes": 2, "dataset_features": 120, "dataset_samples": 24712, "single_frequency_class_detected": false}',
#   'ModelExplainRunId': 'AutoML_17a5bbfd-6834-40c0-9050-e180d725bdc9_ModelExplain'},
#  'inputDatasets': [{'dataset': {'id': 'cf1028a1-aed4-40b5-9d72-7ca15bb3e8fe'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'training_data', 'mechanism': 'Direct'}}, {'dataset': {'id': 'ca56fa1b-9ed1-441a-bf06-fd7b76c6081d'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'validation_data', 'mechanism': 'Direct'}}],
#  'outputDatasets': [],
#  'logFiles': {},
#  'submittedBy': 'Toni Williams'}

# %%
# Retrieve and save your best automl model.

### YOUR CODE HERE ###

best_automl_run = remote_run.get_best_child()

# %%
best_automl_run.download_file(name="outputs/model.pkl", output_file_path="best_model_automl.pkl") #adjust path if needed.

# Register the model
model = Model.register(
    workspace=ws,
    model_path="best_model_automl.pkl",  # Local path to the downloaded model
    model_name="best-automl-model",
    tags={"Training context": "AutoML"},
    description="Best AutoML Model from Optimizing an ML Pipeline in Azure",
)

print("Registered Model ID:", model.id)
# Out:
# Registering model best-automl-model
# Registered Model ID: best-automl-model:1

# %%
from azureml.train.automl.run import AutoMLRun

# %%
automl_run = AutoMLRun(experiment=exp, run_id="AutoML_17a5bbfd-6834-40c0-9050-e180d725bdc9")

# Get the best model's run
best_run, fitted_model = automl_run.get_output()

# %%
from azureml.widgets import RunDetails

RunDetails(best_run).show()
# Out:
# _UserRunWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', '…
# INFO:interpret_community.common.explanation_utils:Using default datastore for uploads
# INFO:interpret_community.common.explanation_utils:Using default datastore for uploads
# INFO:interpret_community.common.explanation_utils:Using default datastore for uploads
# INFO:interpret_community.common.explanation_utils:Using default datastore for uploads

# %%
best_run
# Out:
# Run(Experiment: udacity-project,
# Id: AutoML_17a5bbfd-6834-40c0-9050-e180d725bdc9_45,
# Type: azureml.scriptrun,
# Status: Completed)

# %%
best_run.properties
# Out:
# {'runTemplate': 'automl_child',
#  'pipeline_id': '__AutoML_Ensemble__',
#  'pipeline_spec': '{"pipeline_id":"__AutoML_Ensemble__","objects":[{"module":"azureml.train.automl.ensemble","class_name":"Ensemble","spec_class":"sklearn","param_args":[],"param_kwargs":{"automl_settings":"{\'task_type\':\'classification\',\'primary_metric\':\'accuracy\',\'verbosity\':20,\'ensemble_iterations\':15,\'is_timeseries\':False,\'name\':\'udacity-project\',\'compute_target\':\'c003\',\'subscription_id\':\'d990bb6c-7849-4109-9dd7-6cafa051c8ae\',\'region\':\'eastus2\',\'spark_service\':None}","ensemble_run_id":"AutoML_17a5bbfd-6834-40c0-9050-e180d725bdc9_45","experiment_name":"udacity-project","workspace_name":"mlcloud","subscription_id":"d990bb6c-7849-4109-9dd7-6cafa051c8ae","resource_group_name":"mlcloud"}}]}',
#  'training_percent': '100',
#  'predicted_cost': None,
#  'iteration': '45',
#  '_aml_system_scenario_identification': 'Remote.Child',
#  '_azureml.ComputeTargetType': 'amlctrain',
#  '_azureml.ClusterName': 'c003',
#  'ContentSnapshotId': '5f26edae-3b36-4e6d-a428-c9f035344947',
#  'ProcessInfoFile': 'azureml-logs/process_info.json',
#  'ProcessStatusFile': 'azureml-logs/process_status.json',
#  'run_preprocessor': '',
#  'run_algorithm': 'VotingEnsemble',
#  'ensembled_iterations': '[28, 31, 0, 21, 11, 3, 15, 32]',
#  'ensembled_algorithms': "['XGBoostClassifier', 'XGBoostClassifier', 'LightGBM', 'XGBoostClassifier', 'XGBoostClassifier', 'XGBoostClassifier', 'RandomForest', 'LightGBM']",
#  'ensembled_run_ids': "['AutoML_17a5bbfd-6834-40c0-9050-e180d725bdc9_28', 'AutoML_17a5bbfd-6834-40c0-9050-e180d725bdc9_31', 'AutoML_17a5bbfd-6834-40c0-9050-e180d725bdc9_0', 'AutoML_17a5bbfd-6834-40c0-9050-e180d725bdc9_21', 'AutoML_17a5bbfd-6834-40c0-9050-e180d725bdc9_11', 'AutoML_17a5bbfd-6834-40c0-9050-e180d725bdc9_3', 'AutoML_17a5bbfd-6834-40c0-9050-e180d725bdc9_15', 'AutoML_17a5bbfd-6834-40c0-9050-e180d725bdc9_32']",
#  'ensemble_weights': '[0.14285714285714285, 0.07142857142857142, 0.07142857142857142, 0.07142857142857142, 0.07142857142857142, 0.42857142857142855, 0.07142857142857142, 0.07142857142857142]',
#  'best_individual_pipeline_score': '0.9163631949502307',
#  'best_individual_iteration': '28',
#  'model_output_path': 'outputs/model.pkl',
#  'conda_env_data_location': 'aml://artifact/ExperimentRun/dcid.AutoML_17a5bbfd-6834-40c0-9050-e180d725bdc9_45/outputs/conda_env_v_1_0_0.yml',
#  'model_data_location': 'aml://artifact/ExperimentRun/dcid.AutoML_17a5bbfd-6834-40c0-9050-e180d725bdc9_45/outputs/model.pkl',
#  'model_size_on_disk': '9106962',
#  'scoring_data_location': 'aml://artifact/ExperimentRun/dcid.AutoML_17a5bbfd-6834-40c0-9050-e180d725bdc9_45/outputs/scoring_file_v_1_0_0.py',
#  'scoring_data_location_v2': 'aml://artifact/ExperimentRun/dcid.AutoML_17a5bbfd-6834-40c0-9050-e180d725bdc9_45/outputs/scoring_file_v_2_0_0.py',
#  'scoring_data_location_pbi': 'aml://artifact/ExperimentRun/dcid.AutoML_17a5bbfd-6834-40c0-9050-e180d725bdc9_45/outputs/scoring_file_pbi_v_1_0_0.py',
#  'model_exp_support': 'True',
#  'pipeline_graph_version': '1.0.0',
#  'model_name': 'AutoML17a5bbfd645',
#  'score': '0.9190337460548677',
#  'score_table': 'NaN',
#  'run_properties': 'classification_labels=numpy.array([0, 1]',
#  'pipeline_script': '{"pipeline_id":"__AutoML_Ensemble__","objects":[{"module":"azureml.train.automl.ensemble","class_name":"Ensemble","spec_class":"sklearn","param_args":[],"param_kwargs":{"automl_settings":"{\'task_type\':\'classification\',\'primary_metric\':\'accuracy\',\'verbosity\':20,\'ensemble_iterations\':15,\'is_timeseries\':False,\'name\':\'udacity-project\',\'compute_target\':\'c003\',\'subscription_id\':\'d990bb6c-7849-4109-9dd7-6cafa051c8ae\',\'region\':\'eastus2\',\'spark_service\':None}","ensemble_run_id":"AutoML_17a5bbfd-6834-40c0-9050-e180d725bdc9_45","experiment_name":"udacity-project","workspace_name":"mlcloud","subscription_id":"d990bb6c-7849-4109-9dd7-6cafa051c8ae","resource_group_name":"mlcloud"}}]}',
#  'training_type': 'train_valid',
#  'fit_time': '21',
#  'goal': 'accuracy_max',
#  'primary_metric': 'accuracy',
#  'errors': '{}',
#  'onnx_model_resource': "{'RawColumnNameToOnnxNameMap': {'age': 'age', 'marital': 'marital', 'default': 'default', 'housing': 'housing', 'loan': 'loan', 'month': 'month', 'day_of_week': 'day_of_week', 'duration': 'duration', 'campaign': 'campaign', 'pdays': 'pdays', 'previous': 'previous', 'poutcome': 'poutcome', 'emp.var.rate': 'emp_var_rate', 'cons.price.idx': 'cons_price_idx', 'cons.conf.idx': 'cons_conf_idx', 'euribor3m': 'euribor3m', 'nr.employed': 'nr_employed', 'job_admin.': 'job_admin_', 'job_blue-collar': 'job_blue_collar', 'job_entrepreneur': 'job_entrepreneur', 'job_housemaid': 'job_housemaid', 'job_management': 'job_management', 'job_retired': 'job_retired', 'job_self-employed': 'job_self_employed', 'job_services': 'job_services', 'job_student': 'job_student', 'job_technician': 'job_technician', 'job_unemployed': 'job_unemployed', 'job_unknown': 'job_unknown', 'contact_cellular': 'contact_cellular', 'contact_telephone': 'contact_telephone', 'education_basic.4y': 'education_basic_4y', 'education_basic.6y': 'education_basic_6y', 'education_basic.9y': 'education_basic_9y', 'education_high.school': 'education_high_school', 'education_illiterate': 'education_illiterate', 'education_professional.course': 'education_professional_course', 'education_university.degree': 'education_university_degree', 'education_unknown': 'education_unknown'}, 'InputRawColumnSchema': {'age': 'integer', 'marital': 'integer', 'default': 'integer', 'housing': 'integer', 'loan': 'integer', 'month': 'integer', 'day_of_week': 'integer', 'duration': 'integer', 'campaign': 'integer', 'pdays': 'integer', 'previous': 'integer', 'poutcome': 'integer', 'emp.var.rate': 'floating', 'cons.price.idx': 'floating', 'cons.conf.idx': 'floating', 'euribor3m': 'floating', 'nr.employed': 'floating', 'job_admin.': 'integer', 'job_blue-collar': 'integer', 'job_entrepreneur': 'integer', 'job_housemaid': 'integer', 'job_management': 'integer', 'job_retired': 'integer', 'job_self-employed': 'integer', 'job_services': 'integer', 'job_student': 'integer', 'job_technician': 'integer', 'job_unemployed': 'integer', 'job_unknown': 'integer', 'contact_cellular': 'integer', 'contact_telephone': 'integer', 'education_basic.4y': 'integer', 'education_basic.6y': 'integer', 'education_basic.9y': 'integer', 'education_high.school': 'integer', 'education_illiterate': 'integer', 'education_professional.course': 'integer', 'education_university.degree': 'integer', 'education_unknown': 'integer'}, 'InputOnnxColumnSchema': {'age': 'Int64TensorType', 'marital': 'Int64TensorType', 'default': 'Int64TensorType', 'housing': 'Int64TensorType', 'loan': 'Int64TensorType', 'month': 'Int64TensorType', 'day_of_week': 'Int64TensorType', 'duration': 'Int64TensorType', 'campaign': 'Int64TensorType', 'pdays': 'Int64TensorType', 'previous': 'Int64TensorType', 'poutcome': 'Int64TensorType', 'emp_var_rate': 'FloatTensorType', 'cons_price_idx': 'FloatTensorType', 'cons_conf_idx': 'FloatTensorType', 'euribor3m': 'FloatTensorType', 'nr_employed': 'FloatTensorType', 'job_admin_': 'Int64TensorType', 'job_blue_collar': 'Int64TensorType', 'job_entrepreneur': 'Int64TensorType', 'job_housemaid': 'Int64TensorType', 'job_management': 'Int64TensorType', 'job_retired': 'Int64TensorType', 'job_self_employed': 'Int64TensorType', 'job_services': 'Int64TensorType', 'job_student': 'Int64TensorType', 'job_technician': 'Int64TensorType', 'job_unemployed': 'Int64TensorType', 'job_unknown': 'Int64TensorType', 'contact_cellular': 'Int64TensorType', 'contact_telephone': 'Int64TensorType', 'education_basic_4y': 'Int64TensorType', 'education_basic_6y': 'Int64TensorType', 'education_basic_9y': 'Int64TensorType', 'education_high_school': 'Int64TensorType', 'education_illiterate': 'Int64TensorType', 'education_professional_course': 'Int64TensorType', 'education_university_degree': 'Int64TensorType', 'education_unknown': 'Int64TensorType'}, 'CanEnableBatchMode': True}",
#  'dependencies_versions': '{"azureml-train-automl-runtime": "1.57.0", "azureml-dataset-runtime": "1.57.0", "azureml-mlflow": "1.57.0.post1", "azureml-core": "1.57.0.post1", "azureml-dataprep": "5.1.6", "azureml-telemetry": "1.57.0", "azureml-inference-server-http": "1.3.2", "azureml-automl-core": "1.57.0", "azureml-train-automl-client": "1.57.0", "azureml-train-automl": "1.57.0", "azureml-defaults": "1.57.0.post1", "azureml-automl-runtime": "1.57.0", "azureml-train-restclients-hyperdrive": "1.57.0", "azureml-responsibleai": "1.57.0", "azureml-dataprep-rslex": "2.22.4", "azureml-train-core": "1.57.0", "azureml-dataprep-native": "41.0.0", "azureml-pipeline-core": "1.57.0", "azureml-training-tabular": "1.57.0.post1", "azureml-interpret": "1.57.0"}',
#  'num_cores': '2',
#  'num_logical_cores': '2',
#  'peak_memory_usage': '2113572',
#  'vm_configuration': 'x86_64',
#  'core_hours': '0.01124734777777778',
#  'feature_skus': 'automatedml_sdk_guardrails'}

# %% [markdown]
# ### Clean up deployed resources.

# %%
# Delete the compute target
compute_target.delete()
